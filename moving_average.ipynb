# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Download historical stock data (Apple in this example)
data = yf.download("AAPL", start="2022-01-01", end="2023-01-01")

# Calculate moving averages
data['MA20'] = data['Close'].rolling(window=20).mean()
data['MA50'] = data['Close'].rolling(window=50).mean()

# Plot
plt.figure(figsize=(10,6))
plt.plot(data['Close'], label='AAPL Price')
plt.plot(data['MA20'], label='20-day MA')
plt.plot(data['MA50'], label='50-day MA')
plt.legend()
plt.title("Apple Stock Price with Moving Averages")
plt.show()
# Out:
# /var/folders/zc/kt2cw0hd31g5npjd68mvsm4c0000gn/T/ipykernel_43413/3582449488.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", start="2022-01-01", end="2023-01-01")
# [*********************100%***********************]  1 of 1 completed
